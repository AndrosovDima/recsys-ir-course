# %%
import time
import random
from tqdm import tqdm

import polars as pl

# %%
search_events = (
    pl.read_parquet("search_events.parquet")
    .filter(pl.col("search_query").is_not_null())
)

# %%
search_events.head(5)
# Out:
# shape: (5, 3)
# ┌──────────┬─────────────────────┬──────────────────────┐
# │ user_id  ┆ timestamp           ┆ search_query         │
# │ ---      ┆ ---                 ┆ ---                  │
# │ i32      ┆ datetime[ns]        ┆ str                  │
# ╞══════════╪═════════════════════╪══════════════════════╡
# │ 10904261 ┆ 2024-05-15 15:42:19 ┆ ламбер сыр           │
# │ 2799838  ┆ 2024-05-09 19:12:06 ┆ кетчуп               │
# │ 1156024  ┆ 2024-05-19 21:19:14 ┆ турецкий айран       │
# │ 1969650  ┆ 2024-05-30 08:42:05 ┆ набор для творчества │
# │ 5184152  ┆ 2024-05-13 15:37:06 ┆ чеснок маринованный  │
# └──────────┴─────────────────────┴──────────────────────┘

# %%
search_events.shape
# Out:
# (15712074, 3)

# %% [markdown]
# ## Собираем запросы для индекса

# %%
search_events_grouped = (
    search_events.group_by("search_query").len()
)

# %%
search_events_grouped.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────────┬─────┐
# │ search_query                    ┆ len │
# │ ---                             ┆ --- │
# │ str                             ┆ u32 │
# ╞═════════════════════════════════╪═════╡
# │ амбушюры для airpods            ┆ 1   │
# │ цепт                            ┆ 1   │
# │ блок игрушка                    ┆ 1   │
# │ орзо паста рис                  ┆ 1   │
# │ шнековая соковыжималка геймлюк… ┆ 1   │
# └─────────────────────────────────┴─────┘

# %%
search_events_grouped.shape
# Out:
# (1487083, 2)

# %%
search_events_grouped.filter(pl.col("len") > 1).shape
# Out:
# (538694, 2)

# %%
search_queries_filtered = search_events_grouped.filter(pl.col("len") > 1)

# %%
search_queries_filtered.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────────┬─────┐
# │ search_query                    ┆ len │
# │ ---                             ┆ --- │
# │ str                             ┆ u32 │
# ╞═════════════════════════════════╪═════╡
# │ royal canin gastrointestinal f… ┆ 6   │
# │ курага братья ореховы           ┆ 18  │
# │ килька по гавайски с овощами    ┆ 6   │
# │ подарок маме на юбилей 50       ┆ 2   │
# │ памперсы сени m                 ┆ 5   │
# └─────────────────────────────────┴─────┘

# %%
search_queries_filtered.sort(pl.col("len"), descending=True).head()
# Out:
# shape: (5, 2)
# ┌──────────────┬────────┐
# │ search_query ┆ len    │
# │ ---          ┆ ---    │
# │ str          ┆ u32    │
# ╞══════════════╪════════╡
# │ молоко       ┆ 166186 │
# │ хлеб         ┆ 137364 │
# │ сыр          ┆ 108392 │
# │ мороженое    ┆ 106857 │
# │ яйца         ┆ 75208  │
# └──────────────┴────────┘

# %% [markdown]
# ## Посчитаем популярность запросов

# %%
to_cart_events = pl.read_parquet("to_cart_events.parquet")

# %%
to_cart_events.head()
# Out:
# shape: (5, 4)
# ┌──────────┬─────────────────────┬────────────────┬────────────┐
# │ user_id  ┆ timestamp           ┆ search_query   ┆ product_id │
# │ ---      ┆ ---                 ┆ ---            ┆ ---        │
# │ i32      ┆ datetime[ns]        ┆ str            ┆ i64        │
# ╞══════════╪═════════════════════╪════════════════╪════════════╡
# │ 1423743  ┆ 2024-05-11 20:54:13 ┆ икра красная   ┆ 180730425  │
# │ 37569    ┆ 2024-05-02 08:51:53 ┆ руккола свежая ┆ 357175617  │
# │ 5240641  ┆ 2024-05-16 01:47:09 ┆ сырки дружба   ┆ 356541992  │
# │ 8450453  ┆ 2024-05-28 05:55:01 ┆ фрутоняня      ┆ 141861404  │
# │ 11105338 ┆ 2024-05-02 16:02:37 ┆ пельмени       ┆ 392485080  │
# └──────────┴─────────────────────┴────────────────┴────────────┘

# %%
queries_popularity = (
    to_cart_events.group_by("search_query").len(name="popularity")
)

# %%
queries_popularity.head()
# Out:
# shape: (5, 2)
# ┌──────────────────┬────────────┐
# │ search_query     ┆ popularity │
# │ ---              ┆ ---        │
# │ str              ┆ u32        │
# ╞══════════════════╪════════════╡
# │ rubiscookies     ┆ 1          │
# │ тушь вивен сабо  ┆ 1          │
# │ магнитные шарики ┆ 1          │
# │ щармель          ┆ 2          │
# │ шт               ┆ 6          │
# └──────────────────┴────────────┘

# %%
queries_popularity.sort(pl.col("popularity"), descending=True).head()
# Out:
# shape: (5, 2)
# ┌──────────────┬────────────┐
# │ search_query ┆ popularity │
# │ ---          ┆ ---        │
# │ str          ┆ u32        │
# ╞══════════════╪════════════╡
# │ мороженое    ┆ 173872     │
# │ молоко       ┆ 148224     │
# │ хлеб         ┆ 138253     │
# │ сыр          ┆ 112617     │
# │ творог       ┆ 73395      │
# └──────────────┴────────────┘

# %%
index_queries = (
    search_queries_filtered.join(queries_popularity, on="search_query", how="left")
    .fill_null(value=0)
    .select(
        pl.col("search_query"),
        pl.col("popularity")
    )
)

# %%
index_queries.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────────┬────────────┐
# │ search_query                    ┆ popularity │
# │ ---                             ┆ ---        │
# │ str                             ┆ u32        │
# ╞═════════════════════════════════╪════════════╡
# │ royal canin gastrointestinal f… ┆ 6          │
# │ курага братья ореховы           ┆ 17         │
# │ килька по гавайски с овощами    ┆ 0          │
# │ подарок маме на юбилей 50       ┆ 0          │
# │ памперсы сени m                 ┆ 2          │
# └─────────────────────────────────┴────────────┘

# %% [markdown]
# ## Напишем префиксное дерево поиска

# %%
class TrieNode:
    def __init__(self):
        self._children: dict[str, "TrieNode"] = {}
        self._is_end = False
        self._popularity = 0

    def get_popularity(self) -> int:
        return self._popularity

    def set_popularity(self, popularity: int) -> None:
        self._popularity = popularity

    def is_end(self) -> bool:
        return self._is_end

    def mark_as_end(self) -> None:
        self._is_end = True

    def add_child(self, char: str) -> None:
        self._children[char] = TrieNode()

    def get_children(self) -> dict[str, "TrieNode"]:
        return self._children

# %%
class Trie:
    def __init__(self):
        self._root = TrieNode()

    def insert(self, query: str, popularity: int) -> None:
        node = self._root
        for char in query:
            children = node.get_children()
            if char not in children:
                node.add_child(char)
            node = children[char]
        node.mark_as_end()
        node.set_popularity(popularity)

    def get_completions(self, prefix: str, limit: int = -1) -> list[tuple[str, int]]:
        completions = []
        node_starts_with_prefix = self._get_node_starts_with_prefix(prefix)
        if node_starts_with_prefix is None:
            return completions

        self._collect_completions(node_starts_with_prefix, prefix, completions)
        return sorted(completions, key=lambda x: -x[1])[:limit if limit > 0 else None]

    def _get_node_starts_with_prefix(self, prefix: str) -> TrieNode:
        node = self._root
        for char in prefix:
            children = node.get_children()
            if char not in children:
                return None
            node = children[char]
        return node

    def _collect_completions(self, node: TrieNode, current_prefix, completions) -> None:
        if node.is_end():
            completions.append((current_prefix, node.get_popularity()))
        for char, child_node in node.get_children().items():
            self._collect_completions(child_node, current_prefix + char, completions)

# %%
trie = Trie()

# %%
trie.insert("молоко", 100)
trie.insert("машина", 6)
trie.insert("молоток", 9)
trie.insert("молоко пастеризованное", 13)

# %%
trie.get_completions("мо")
# Out:
# [('молоко', 100), ('молоко пастеризованное', 13), ('молоток', 9)]

# %% [markdown]
# ## Добавим в дерево наши запросы

# %%
trie = Trie()

# %%
for query, popularity in tqdm(index_queries.iter_rows()):
    trie.insert(query, popularity)
# Out:
# 538694it [00:05, 96217.86it/s]

# %%
trie.get_completions("ма", limit=100)
# Out:
# [('макароны', 50646),
#  ('масло сливочное', 42951),
#  ('майонез', 42640),
#  ('масло подсолнечное', 16380),
#  ('мармелад', 15554),
#  ('масло сливочное 82,5', 10178),
#  ('масло', 9277),
#  ('макароны barilla', 5658),
#  ('масло растительное', 5352),
#  ('маслины', 4368),
#  ('масло оливковое', 4213),
#  ('манго', 4064),
#  ('мандарины', 3935),
#  ('майонез слобода', 3698),
#  ('мармелад жевательный', 3172),
#  ('маслины без косточки', 2424),
#  ('маскарпоне', 2168),
#  ('малина', 1807),
#  ('манка', 1767),
#  ('магнат', 1660),
#  ('манго сушеный', 1610),
#  ('майонез провансаль', 1573),
#  ('мандарины свежие', 1514),
#  ('маринованные огурцы', 1475),
#  ('мажитэль', 1437),
#  ('масло подсолнечное рафинированное', 1375),
#  ('мацони', 1366),
#  ('масло гхи', 1284),
#  ('маска для волос', 1241),
#  ('макароны без глютена', 1211),
#  ('маасдам', 1210),
#  ('макароны макфа', 1205),
#  ('манная крупа', 1112),
#  ('маска для лица', 1064),
#  ('макароны из твердых сортов пшеницы', 1059),
#  ('мармеладки', 1009),
#  ('майонез легкий', 1006),
#  ('магги', 997),
#  ('макароны детские', 972),
#  ('масло оливковое extra virgin', 797),
#  ('манка крупа', 780),
#  ('масса творожная', 770),
#  ('магний', 769),
#  ('макароны шебекинские', 762),
#  ('масло растительное подсолнечное', 755),
#  ('марс', 678),
#  ('мангал', 678),
#  ('магнат мороженое', 645),
#  ('макароны барилла', 619),
#  ('маскарпоне сыр', 592),
#  ('макфа', 587),
#  ('маргарин', 569),
#  ('маццарела сыр', 519),
#  ('маршмеллоу', 518),
#  ('макадамия', 515),
#  ('махеев', 511),
#  ('малоежка', 506),
#  ('макаруны', 502),
#  ('малина замороженная', 480),
#  ('махеев джем', 465),
#  ('маасдам сыр', 458),
#  ('малина свежая', 457),
#  ('мандарин', 454),
#  ('майонез постный', 431),
#  ('масло сливочное82.5', 430),
#  ('магний в6', 418),
#  ('малиновое варенье', 401),
#  ('масло подсолнечное нерафинированное', 389),
#  ('мамба', 383),
#  ('масло растительное рафинированное', 369),
#  ('макарон', 346),
#  ('масло безлактозное', 339),
#  ('макароны бантики', 330),
#  ('масло слив', 329),
#  ('маракуйя', 328),
#  ('манго свежий', 327),
#  ('матча', 323),
#  ('мажитель', 297),
#  ('макфа макароны', 296),
#  ('масса творожная с изюмом', 294),
#  ('мак', 291),
#  ('малютка 4', 287),
#  ('масло авокадо', 286),
#  ('мандарины сладкие', 278),
#  ('манго сушеный без сахара', 273),
#  ('мангал одноразовый', 271),
#  ('маш', 267),
#  ('масло топленое', 264),
#  ('макароны цельнозерновые', 261),
#  ('маргарин для выпечки', 260),
#  ('мармелад кислый', 252),
#  ('макороны', 249),
#  ('машинка игрушка', 244),
#  ('малютка 2', 244),
#  ('майонез махеев', 242),
#  ('масло нерафинированное', 237),
#  ('масло виноградной косточки', 235),
#  ('мармелад ударница', 234),
#  ('маска', 233),
#  ('мажитэль напиток', 232)]

# %% [markdown]
# ## Добавим возможность нечеткого (fuzzy) поиска

# %%
class FuzzyTrie:
    def __init__(self):
        self._root = TrieNode()

    def insert(self, query: str, popularity: int) -> None:
        node = self._root
        for char in query:
            children = node.get_children()
            if char not in children:
                node.add_child(char)
            node = children[char]
        node.mark_as_end()
        node.set_popularity(popularity)

    def get_completions(self, prefix: str, fuzziness: int = 0, limit: int = -1) -> list[tuple[str, int]]:
        completions = []
        
        def dfs(node: TrieNode, current_prefix: str, i: int, edits: int):
            if edits > fuzziness:
                return

            if i == len(prefix):
                self._collect_completions(node, current_prefix, completions)
                return

            current_char = prefix[i]

            children = node.get_children()

            # точный поиск
            if current_char in children:
                dfs(children[current_char], current_prefix + current_char, i + 1, edits)

            # замена последнего символа
            for char, child_node in children.items():
                if current_char != char:
                    dfs(child_node, current_prefix + char, i + 1, edits + 1)

            # вставка символа (например, "молко" вместо "молоко")
            for char, child_node in children.items():
                dfs(child_node, current_prefix + char, i, edits + 1)

            # удаление символа
            dfs(node, current_prefix, i + 1, edits + 1)
            

        dfs(self._root, "", 0, 0)
        unique_completions = {}
        for query, popularity in completions:
            if query not in unique_completions:
                unique_completions[query] = popularity

        return sorted(unique_completions.items(), key=lambda x: -x[1])

    def _collect_completions(self, node: TrieNode, current_prefix, completions) -> None:
        if node.is_end():
            completions.append((current_prefix, node.get_popularity()))
        for char, child_node in node.get_children().items():
            self._collect_completions(child_node, current_prefix + char, completions)

# %%
fuzzy_trie = FuzzyTrie()

# %%
fuzzy_trie.insert("молоко", 100)
fuzzy_trie.insert("машина", 6)
fuzzy_trie.insert("молоток", 9)
fuzzy_trie.insert("молоко пастеризованное", 13)

# %%
fuzzy_trie.get_completions("мош", fuzziness=1, limit=100)
# Out:
# [('молоко', 100),
#  ('молоко пастеризованное', 13),
#  ('молоток', 9),
#  ('машина', 6)]

# %%
fuzzy_trie = FuzzyTrie()

# %%
for query, popularity in tqdm(index_queries.iter_rows()):
    fuzzy_trie.insert(query, popularity)
# Out:
# 538694it [00:05, 90979.86it/s]

# %%
fuzzy_trie.get_completions("мало", fuzziness=1, limit=100)
# Out:
# [('молоко', 148224),
#  ('масло сливочное', 42951),
#  ('майонез', 42640),
#  ('молоко 3,2', 17658),
#  ('масло подсолнечное', 16380),
#  ('молоко безлактозное', 14275),
#  ('масло сливочное 82,5', 10178),
#  ('масло', 9277),
#  ('масло растительное', 5352),
#  ('молоко ультрапастеризованное', 4436),
#  ('масло оливковое', 4213),
#  ('майонез слобода', 3698),
#  ('мыло жидкое для рук', 3692),
#  ('молоко 2,5', 3444),
#  ('мыло', 3275),
#  ('молоко детское', 2942),
#  ('молоко кокосовое', 2739),
#  ('молоко растительное', 2543),
#  ('молочный коктейль', 2352),
#  ('молоко агуша', 2241),
#  ('малина', 1807),
#  ('сало', 1786),
#  ('мыло жидкое', 1604),
#  ('молоко топленое', 1592),
#  ('майонез провансаль', 1573),
#  ('масло подсолнечное рафинированное', 1375),
#  ('мацони', 1366),
#  ('масло гхи', 1284),
#  ('молоко миндальное', 1257),
#  ('молоко эконива', 1218),
#  ('майонез легкий', 1006),
#  ('мыло твердое', 976),
#  ('мыло для рук', 957),
#  ('молоко parmalat', 930),
#  ('молоко пармалат', 909),
#  ('молочный ломтик', 870),
#  ('масло оливковое extra virgin', 797),
#  ('палочки ватные', 768),
#  ('масло растительное подсолнечное', 755),
#  ('молочный шоколад', 715),
#  ('палочки', 711),
#  ('молоко банановое', 685),
#  ('молоко простоквашино', 617),
#  ('молоко безлактозное 1 л', 617),
#  ('молоко 3.2', 567),
#  ('молоко сгущенное', 561),
#  ('молоко ультрапастеризованное 3.2', 538),
#  ('молоко безлактозное parmalat', 523),
#  ('молоко село зеленое', 521),
#  ('молоко 1,5 процента', 516),
#  ('малоежка', 506),
#  ('малина замороженная', 480),
#  ('молоко 2,5 процента', 476),
#  ('малина свежая', 457),
#  ('молоко 2.5', 456),
#  ('сало белорусское', 452),
#  ('мыло для рук жидкое', 451),
#  ('молоко 1.5%', 433),
#  ('майонез постный', 431),
#  ('молоко 1,5', 431),
#  ('масло сливочное82.5', 430),
#  ('молоко агуша детское', 419),
#  ('молоко овсяное', 409),
#  ('малиновое варенье', 401),
#  ('масло подсолнечное нерафинированное', 389),
#  ('молотый кофе', 387),
#  ('масло растительное рафинированное', 369),
#  ('молоко пармалат 3,5%', 359),
#  ('молоко 3,2 ультрапастеризованное', 343),
#  ('масло безлактозное', 339),
#  ('масло слив', 329),
#  ('молоко пастеризованное', 329),
#  ('молоко обезжиренное', 320),
#  ('палочки крабовые', 317),
#  ('молоко домик в деревне 3,2', 313),
#  ('молоко миндальное без сахара', 307),
#  ('палочки соленые', 292),
#  ('малютка 4', 287),
#  ('молок', 287),
#  ('масло авокадо', 286),
#  ('молоко село зеленое 3,2', 274),
#  ('палочки кукурузные', 270),
#  ('масло топленое', 264),
#  ('молоко эконива 3,2', 259),
#  ('мыло хозяйственное', 256),
#  ('макороны', 249),
#  ('малютка 2', 244),
#  ('молоко агуша 1 литр', 244),
#  ('майонез махеев', 242),
#  ('молоко растительное без сахара', 239),
#  ('масло нерафинированное', 237),
#  ('масло виноградной косточки', 235),
#  ('молоко тема', 233),
#  ('молоко правильное', 232),
#  ('масло сливочное вологодское', 231),
#  ('молоко 0,5', 229),
#  ('масло кокосовое', 226),
#  ('молоко козье', 222),
#  ('молокр', 222),
#  ('масло для волос', 210),
#  ('молоко кокосовое aroy d', 210),
#  ('молоко ультрапастеризованное 2,5', 210),
#  ('малютка 3', 206),
#  ('масло сливочное безлактозное', 206),
#  ('молоко 3,2 %', 202),
#  ('молочная каша детская', 198),
#  ('масло гхи топленое', 197),
#  ('молоко пискаревское', 197),
#  ('масло для загара', 196),
#  ('молодой картофель', 189),
#  ('масло кунжутное', 182),
#  ('молоко детское агуша', 182),
#  ('молоко цельное', 177),
#  ('молоко пармалат 1,8', 176),
#  ('масло сливочное вкуснотеево', 174),
#  ('масло подсолнечное рафинированное 1л', 172),
#  ('малютка', 166),
#  ('молоко 1%', 164),
#  ('молоко 2л', 164),
#  ('майонез низкокалорийный', 163),
#  ('мыло детское', 162),
#  ('масло шоколадное', 161),
#  ('молоко отборное', 161),
#  ('масло для тела', 158),
#  ('молоко 0,2', 158),
#  ('палочки ушные', 158),
#  ('масло нерафинированное подсолнечное', 155),
#  ('молоко planto', 154),
#  ('малютка 1', 151),
#  ('масло безлактозное сливочное', 151),
#  ('молоко 3,5', 151),
#  ('масло кукурузное', 150),
#  ('молоко ультрапастеризованное 3,2', 149),
#  ('маковый рулет', 145),
#  ('малоежка детское питание', 142),
#  ('масло оливковое рафинированное', 138),
#  ('молоко parmalat 3,5', 134),
#  ('молочный улун', 128),
#  ('молоко зеленое село', 126),
#  ('молокл', 126),
#  ('малина протертая', 125),
#  ('молоко 12шт', 125),
#  ('мыло synergetic', 125),
#  ('молочная культура', 121),
#  ('молоко эконива 2,5', 120),
#  ('молоко 6%', 120),
#  ('майонез чистый', 119),
#  ('мацони армянский', 119),
#  ('малосольные огурцы', 118),
#  ('молоко домик', 118),
#  ('майонещ', 117),
#  ('молоко агрокомплекс', 113),
#  ('мамло', 112),
#  ('молоко 0.5%', 112),
#  ('молоко маленькое', 111),
#  ('молоко 200мл', 111),
#  ('молоко топленное', 109),
#  ('масло слобода', 108),
#  ('масло брест литовск', 108),
#  ('молочные продукты', 107),
#  ('молочная каша', 107),
#  ('майоне', 105),
#  ('мацонез', 105),
#  ('молочный коктейль детский', 105),
#  ('масло экомилк', 104),
#  ('мыло для рук твердое', 104),
#  ('масло для душа', 103),
#  ('молочко для тела', 101),
#  ('молоео', 99),
#  ('майонез сметанный', 97),
#  ('молоко 12 шт', 97),
#  ('мыло для интимной гигиены', 97),
#  ('марожные пломбир', 96),
#  ('молока', 96),
#  ('шалот', 96),
#  ('масло оливковое нерафинированное', 95),
#  ('молоко соевое', 95),
#  ('масло президент', 93),
#  ('масло топленое гхи', 93),
#  ('молоко viola', 93),
#  ('молоко кокосовое без сахара', 92),
#  ('молоко ванильное', 92),
#  ('масло растительное нерафинированное', 91),
#  ('масло рафинированное', 91),
#  ('молоко parmalat 1,8', 91),
#  ('молоко простоквашино 3,2', 90),
#  ('молоко 3,2 домик в деревне', 90),
#  ('молоко 1л', 89),
#  ('масло 82,5 сливочное', 88),
#  ('молоко кокос', 87),
#  ('масло вологодское', 86),
#  ('молоко для капучино', 86),
#  ('майонез я люблю готовить', 85),
#  ('молоко 3,2 ультрапастеризованное 1 л', 85),
#  ('молоко 1,8', 85),
#  ('майонез ряба', 84),
#  ('майонез оливковый', 83),
#  ('масло тыквенное', 82),
#  ('молоко пармалат безлактозное', 82),
#  ('молочный', 81),
#  ('шалот лук', 80),
#  ('молоко топленое эконива топленое', 79),
#  ('мал золотник', 78),
#  ('масло оливковое для жарки', 78),
#  ('майонез чистый я люблю готовить', 77),
#  ('молоко безлактозное parmalat 1,8', 77),
#  ('молоко детское 0.2', 77),
#  ('мыло кусковое', 77),
#  ('молоко простоквашино 2,5%', 76),
#  ('палочки хлебные', 76),
#  ('молоко домик в деревне 2,5', 75),
#  ('сало копченое', 75),
#  ('майонез слобода оливковый', 74),
#  ('майонез 800мл', 74),
#  ('молоко сгущеное', 74),
#  ('молоко шоколадное', 73),
#  ('молоко без лактозы parmalat', 73),
#  ('молочная смесь', 73),
#  ('майонез скит', 72),
#  ('молоко коровье', 72),
#  ('молокуши', 71),
#  ('масло ароматное подсолнечное', 70),
#  ('молоко асеньевская ферма', 70),
#  ('молоко экомилк', 69),
#  ('масло эконива', 68),
#  ('масло сливочное 72,5', 67),
#  ('молоко чабан', 67),
#  ('майонез на перепелиных яйцах', 66),
#  ('масло кокосовое для жарки', 66),
#  ('маонез', 66),
#  ('молоко пастеризованное 3,2', 66),
#  ('молочные сосиски', 66),
#  ('масло altero', 65),
#  ('молоко валио', 65),
#  ('молоуо', 65),
#  ('маалокс', 64),
#  ('молочная колбаса', 64),
#  ('мыло жидкое synergetic', 63),
#  ('молоко без сахара', 62),
#  ('молоко вкуснотеево', 62),
#  ('мыло антибактериальное', 62),
#  ('мацони кавказский', 61),
#  ('масло трюфельное', 61),
#  ('масло шоколадное сливочное', 60),
#  ('молоко арсеньевское', 60),
#  ('молоко зеленое село 3.2', 60),
#  ('молоко valio', 60),
#  ('молоко правильное молоко', 59),
#  ('молоко кубанский молочник', 59),
#  ('молоко 1.5', 59),
#  ('молоко фермерское', 59),
#  ('молоко фундук', 58),
#  ('мыло синергетик', 58),
#  ('масло вкуснотеево сливочное', 57),
#  ('масло альтеро', 57),
#  ('молоко бариста', 57),
#  ('молоко 1,8 parmalat', 57),
#  ('молочные коктейли', 57),
#  ('палочки рыбные', 57),
#  ('молоко 0.2', 56),
#  ('молоко топлёное', 56),
#  ('палочки творожные', 56),
#  ('масло для жарки', 55),
#  ('молоко фрутоняня', 55),
#  ('майонез перепелиные', 53),
#  ('масло подсолнечное ароматное', 53),
#  ('молоко кокосовое бариста', 53),
#  ('палочки для ушей', 53),
#  ('майонез zero', 52),
#  ('молоко кубанская буренка', 52),
#  ('молоко альпро', 52),
#  ('молоко цельное питьевое', 52),
#  ('молодая капуста', 52),
#  ('майонез провансаль московский', 51),
#  ('масло сливочное 400гр', 51),
#  ('масло рафинированное подсолнечное', 50),
#  ('масло авокадо для жарки', 50),
#  ('молоко 3.2 ультрапастеризованное', 50),
#  ('молоко 1,4 л', 50),
#  ('молоко parmalat безлактозное', 50),
#  ('мыло для рук synergetic', 50),
#  ('масло ростиельноее', 49),
#  ('молоко детское с 8 месяцев', 49),
#  ('молодая картошка', 49),
#  ('мыло для посуды', 49),
#  ('майонкз', 48),
#  ('масло для массажа', 48),
#  ('масло президент president', 48),
#  ('молоко упаковка 12 шт', 48),
#  ('молочный ломтик kinder', 48),
#  ('палочки кукурузные фрутоняня', 48),
#  ('масло растительное подсолнечное рафинированное', 47),
#  ('масло спрей', 47),
#  ('молоко сернур', 47),
#  ('молоко васильевой', 47),
#  ('молоко альтернативное', 47),
#  ('масло вологодское сливочное', 46),
#  ('молоко правильное 2 литра', 46),
#  ('молоко банан', 46),
#  ('молоко овсяное немолоко', 46),
#  ('молоко агуша 200 мл', 46),
#  ('молоко 1', 46),
#  ('молочный коктель', 46),
#  ('мыло твердое для рук', 46),
#  ('молоко 1.8', 45),
#  ('мыло детское жидкое 0+', 45),
#  ('мрлоко', 45),
#  ('масло сливочное 82,5 вологодское', 44),
#  ('масло president', 44),
#  ('алоэ', 44),
#  ('масло детское', 43),
#  ('молоко 3,2 село зеленое', 43),
#  ('молоко 1 л', 43),
#  ('молоко 200 мл', 43),
#  ('мыло детское жидкое', 43),
#  ('масло массажное', 42),
#  ('молоко тетрапак', 42),
#  ('молоко 2,5 ультрапастеризованное', 42),
#  ('молочная смесь детская', 42),
#  ('масло сливочнок', 41),
#  ('масло олейна', 41),
#  ('масло кокосовое нерафинированное', 41),
#  ('молоко виола', 41),
#  ('молоко2,5', 41),
#  ('масло подсолнечное слобода', 40),
#  ('масло тысяча озер', 40),
#  ('масло ароматное', 40),
#  ('молочная каша детская жидкая', 40),
#  ('алоэ гель', 40),
#  ('малиновый джем', 39),
#  ('молоко сгущенное вареное', 39),
#  ('молоко для кофемашины', 39),
#  ('молоко ореховое', 39),
#  ('алое', 39),
#  ('мароженное', 38),
#  ('масло слобода подсолнечное', 38),
#  ('молоко домик в деревне', 38),
#  ('молоко 2 литра', 38),
#  ('майонез маленький', 37),
#  ('майонез рикко', 37),
#  ('масло сливочное соленое', 37),
#  ('молоко рузское', 37),
#  ('молоко село', 37),
#  ('молоко 3,2 эконива', 37),
#  ('молоко 1 литр', 37),
#  ('малина варенье', 36),
#  ('масло 82', 36),
#  ('молоко коровка из кореновки', 36),
#  ('молокуши сосиски', 36),
#  ('молочный ломтик киндер', 36),
#  ('малютка 3 смесь', 35),
#  ('майоннз', 35),
#  ('масло кукурузное рафинированное', 35),
#  ('мамло сливочное', 35),
#  ('молоко 2,5%', 35),
#  ('молоко упаковка ультрапастеризованное 12 шт', 35),
#  ('молоко чебурашкины', 35),
#  ('сало соленое', 35),
#  ('масло кунжутное нерафинированное', 34),
#  ('масло альтеро с добавлением оливкового', 34),
#  ('масло безлактозное parmalat', 34),
#  ('молоко озон', 34),
#  ('молоко миндаль', 34),
#  ('молоко гречневое', 34),
#  ('молоко 200', 34),
#  ('молоко чудо', 34),
#  ('мыло жидкое детское', 34),
#  ('мыло хозяйственное для стирки', 34),
#  ('молоко пломбир', 33),
#  ('молоко безлактозное простоквашино', 33),
#  ('молоко сарафаново', 33),
#  ('молоко 3,2 простоквашино', 33),
#  ('молоко тема детское', 33),
#  ('молокоотсос', 33),
#  ('молочные каши для детей', 33),
#  ('мыло синергетик для рук', 33),
#  ('мыло 5 литров жидкое', 33),
#  ('мллоко', 33),
#  ('малое филе', 32),
#  ('малютка 2 смесь', 32),
#  ('масло сливочное экомилк', 32),
#  ('масло подсолнечное без запаха', 32),
#  ('молоко село зеленое 2,5', 32),
#  ('молоко 0,5 л', 32),
#  ('молоко вкусняев', 32),
#  ('молоко обнимама', 32),
#  ('мыло антибактериальное жидкое', 32),
#  ('мыло dove', 32),
#  ('малоко', 31),
#  ('масло сливочное президент', 31),
#  ('масло гхи для жарки', 31),
#  ('молоко безлактозное пармалат', 31),
#  ('молоко стерилизованное', 31),
#  ('молоко сгущенное рогачевъ', 31),
#  ('молоко агуша 500', 31),
#  ('молоко 2 л', 31),
#  ('мыло твердое туалетное', 31),
#  ('малиновый сок', 30),
#  ('майонез heinz', 30),
#  ('масло для кутикулы', 30),
#  ('масло сливо', 30),
#  ('масло сливочное 82,5 вкуснотеево', 30),
#  ('масло с запахом подсолнечное', 30),
#  ('молоко 0.5', 30),
#  ('молоко 3.5', 30),
#  ('молоко 500мл', 30),
#  ('пало санто', 30),
#  ('мароженое', 29),
#  ('масло для салата', 29),
#  ('масло для губ', 29),
#  ('масло сливочное брест литовск', 29),
#  ('масло вкуснотеево', 29),
#  ('молоко село зеленое 3 2', 29),
#  ('молочница', 29),
#  ('масло соивочное', 28),
#  ('молоко 0', 28),
#  ('молоко 0,05', 28),
#  ('молоко 3,2 пармалат', 28),
#  ('молоко 3,5 пармалат', 28),
#  ('молоко миндальное бариста', 28),
#  ('молоко barista', 28),
#  ('молодая кукуруза', 28),
#  ('мыло для стирки', 28),
#  ('малиновое варенье натуральное', 27),
#  ('мальт паста для кошек', 27),
#  ('майонез ведро', 27),
#  ('майонез 800', 27),
#  ('масло растит', 27),
#  ('масло для загара на солнце', 27),
#  ('масло сливочное 82', 27),
#  ('масло льняное нерафинированное', 27),
#  ('масло авокадо нерафинированное', 27),
#  ('молоко безлактозное 3,5', 27),
#  ('молоко сернурское', 27),
#  ('молоко вкусвилл', 27),
#  ('молоко можайское', 27),
#  ('молочный напиток', 27),
#  ('молочко для тела увлажнение', 27),
#  ('малоежка клубника', 26),
#  ('масло сливочное вкуснотеево 82,5', 26),
#  ('масло селедочное', 26),
#  ('масло льняное', 26),
#  ('масло брест', 26),
#  ('масло 82,5', 26),
#  ('молоко 2.5 ультрапастеризованное', 26),
#  ('мыло жидкое антибактериальное', 26),
#  ('млоко', 26),
#  ('палочки с ограничителем детские', 26),
#  ('масло сливочное 82.5', 25),
#  ('масло подсолнечное нерафинированное ароматное', 25),
#  ('молоко пекан', 25),
#  ('молоко братья чебурашкины', 25),
#  ('молоко 4%-6%', 25),
#  ('молоко 0.05', 25),
#  ('молоко валио 3,2%', 25),
#  ('молоко эко нива', 25),
#  ('молоко ультра', 25),
#  ('молоко econiva', 25),
#  ('палочки с солью', 25),
#  ('малосольные огурцы чипсы лейс', 24),
#  ('майонез 400 мл', 24),
#  ('масло рисовое', 24),
#  ('масло нерафинированное подсолнечное ароматное', 24),
#  ('молоко 3', 24),
#  ('молоко 1.4', 24),
#  ('молоко ультрапастеризованное 1,5', 24),
#  ('молокт', 24),
#  ('мыло duru', 24),
#  ('алоэ напиток', 24),
#  ('маковый', 23),
#  ('майонез натуральный', 23),
#  ('масло сливочное 82,5 президент', 23),
#  ('масло сливочное 100 гр', 23),
#  ('масло сливочное эконива', 23),
#  ('масло золотая семечка подсолнечное', 23),
#  ('молоко 3,2 пастеризованное', 23),
#  ('молоко хозяйство васильевой', 23),
#  ('молокоотсос электрический', 23),
#  ('молочный коктейль фрутоняня', 23),
#  ('палочки ватные с ограничителем', 23),
#  ('сало белорусское соленое', 23),
#  ('майонез махеев с лимонным соком', 22),
#  ('майонез ricco', 22),
#  ('майонез я люблю готовить без сахара', 22),
#  ('масло сливоч', 22),
#  ('масло сливочное вологодское 82,5', 22),
#  ('масло топленое сливочное', 22),
#  ('масло брест литовское', 22),
#  ('молоко безлактозное parmalat 3,5', 22),
#  ('молоко свежее завтра', 22),
#  ('молоко калининское', 22),
#  ('молоко 0,05 жирность', 22),
#  ('молоко очень важная корова', 22),
#  ('молоко 1,4', 22),
#  ('молоко тема 0,5 тёма', 22),
#  ('молоко 2,5 эконива', 22),
#  ('молотый имбирь', 22),
#  ('молочный улун чай', 22),
#  ('молочные ломтики', 22),
#  ('мыло туалетное', 22),
#  ('мыло дуру', 22),
#  ('малютка про комфорт', 21),
#  ('майонез без сахара я люблю готовить', 21),
#  ('масло под', 21),
#  ('масло оливковое для салата', 21),
#  ('масло 72,5', 21),
#  ('молоко простоквашино безлактозное', 21),
#  ('молоко безлактозное 1 л простоквашино', 21),
#  ('молоко 0,5%', 21),
#  ('молоко 1,5%', 21),
#  ('молоко 2.5%', 21),
#  ('молоко bite', 21),
#  ('молочная', 21),
#  ('молочное', 21),
#  ('мыло дав', 21),
#  ('мыло дидкое', 21),
#  ('мыло жидкое для рук антибактериальное', 21),
#  ('палочки морковные', 21),
#  ('малютка комфорт про', 20),
#  ('малютка 4 смесь', 20),
#  ('масло растительное рафинированное подсолнечное', 20),
#  ('масло сливочное82.5 вкуснотеево', 20),
#  ('масло тыквенное kotanyi', 20),
#  ('масло altero с добавлением оливкового', 20),
#  ('моло', 20),
#  ('молоко банановое без сахара', 20),
#  ('молоко немолоко', 20),
#  ('молоко славянские кружева', 20),
#  ('молоко детское тема', 20),
#  ('молоко 12', 20),
#  ('мыло для кухни жидкое', 20),
#  ('мыло кусковое для рук', 20),
#  ('палочки соленые saltletts', 20),
#  ('фалосы для женщин', 20),
#  ('малина с сахаром', 19),
#  ('марожни', 19),
#  ('майонез слобода 800', 19),
#  ('майонез лёгкий', 19),
#  ('майонез 200 мл', 19),
#  ('масло соленое сливочное', 19),
#  ('масло гидрофильное', 19),
#  ('масло мст', 19),
#  ('молоко с печеньем фрутоняня', 19),
#  ('молоко 12 штук', 19),
#  ('молоко ekoniva', 19),
#  ('молока 3,2', 19),
#  ('молочные продукты для детей', 19),
#  ('мыло для посуды жидкое', 19),
#  ('мыло бархатные ручки жидкое', 19),
#  ('мыло ушастый нянь', 19),
#  ('палочки для канапе', 19),
#  ('малиновое', 18),
#  ('малютка 1 смесь', 18),
#  ('майонез мжк', 18),
#  ('майонез постный слобода', 18),
#  ('майонез 0%', 18),
#  ('майонез 30%', 18),
#  ('мацони кавказский долгожитель', 18),
#  ('масло подсолнечное с оливковым', 18),
#  ('масло экомилк сливочное', 18),
#  ('молоко безлактозное 3,2', 18),
#  ('молоко для детей', 18),
#  ('молоко кружева', 18),
#  ('молоко валио 1,5', 18),
#  ('молоко 1,5 жирность', 18),
#  ('молоко 1.4 л', 18),
#  ('молоко 1 %', 18),
#  ('молоко 1400', 18),
#  ('молоко 500', 18),
#  ('молоко 2', 18),
#  ('молоко 2.5 простоквашино', 18),
#  ('молоко жирное', 18),
#  ('молоко green milk', 18),
#  ('молоко1,5', 18),
#  ('молотый', 18),
#  ('молочная смесь 4', 18),
#  ('мыло жидкое для рук 5 л', 18),
#  ('мыло жилкое', 18),
#  ('фалос', 18),
#  ('маком', 17),
#  ('майонез мистер рикко', 17),
#  ('майонез провансаль 700', 17),
#  ('майонез легкий calve', 17),
#  ('масло сл', 17),
#  ('масло сливочное 82,5 400г', 17),
#  ('масло сдивочное', 17),
#  ('масло подс', 17),
#  ('масло подсолнечное олейна', 17),
#  ('масло золотая семечка', 17),
#  ('масло из виноградных косточек', 17),
#  ('молоко село зелёное', 17),
#  ('молоко козье село зеленое', 17),
#  ('молоко козье питьевое', 17),
#  ('молоко в бутылке', 17),
#  ('молоко фундучное', 17),
#  ('молоко тема 0,2', 17),
#  ('молочный шоколад кондитерский', 17),
#  ('молоо', 17),
#  ('мыло туалетное твердое', 17),
#  ('мыло жидкое для рук synergetic', 17),
#  ('мыло банное', 17),
#  ('палочки ватные детские', 17),
#  ('палочки вафельные', 17),
#  ('малоежка педиашур', 16),
#  ('майонез московский провансаль', 16),
#  ('майонез я люблю готовить чистый', 16),
#  ('масло растительное рафинированное 1 л', 16),
#  ('масло сливочное тысяча озер', 16),
#  ('масло сливочное 500гр', 16),
#  ('масло сливочное шоколадное', 16),
#  ('масло с трюфелем', 16),
#  ('масло гхи атман', 16),
#  ('масло подсол', 16),
#  ('масло подсолнечное 5литров', 16),
#  ('масло оливковое 1л', 16),
#  ('масло оливковое monini', 16),
#  ('молоко питьевое', 16),
#  ('молоко планто', 16),
#  ('молоко без лактозы', 16),
#  ('молоко соевое без сахара', 16),
#  ('молоко свежее', 16),
#  ('молоко 0%', 16),
#  ('молоко zinus', 16),
#  ('молочные каши для детей жидкие', 16),
#  ('молодой чеснок', 16),
#  ('мыло для тела', 16),
#  ('мыло от пятен для стирки', 16),
#  ('палочки фрутоняня кукурузные', 16),
#  ('алое гель для лица', 16),
#  ('малосольная форель', 15),
#  ('малиновый сироп', 15),
#  ('малина протертая с сахаром', 15),
#  ('малютка комфорт про 0', 15),
#  ('марожное', 15),
#  ('майонез диетический', 15),
#  ('майонез хайнц', 15),
#  ('масло мливочное', 15),
#  ('масло чабан', 15),
#  ('масло виноградной косточки monini', 15),
#  ('молоко пармолат', 15),
#  ('молоко пастеризованное 2,5', 15),
#  ('молоко пискаревское пастеризованное,2,5% 1 л', 15),
#  ('молоко натуральное', 15),
#  ('молоко растительное planto', 15),
#  ('молоко клубничное', 15),
#  ('молоко обычное', 15),
#  ('молоко агрокомплекс 3,2%', 15),
#  ('молоко 1400 мл', 15),
#  ('молочный десерт', 15),
#  ('мелониловая губка', 15),
#  ('мыло от пятен', 15),
#  ('мвло', 15),
#  ('палочки детские', 15),
#  ('палочки фрутоняня', 15),
#  ('саломка', 15),
#  ('малое куриное филе', 14),
#  ('малиновый чай', 14),
#  ('майонез большой', 14),
#  ('майонез веган', 14),
#  ('майонез рико', 14),
#  ('майонез ряба оливковый', 14),
#  ('майонз', 14),
#  ('майогез', 14),
#  ('масло для массажа детское', 14),
#  ('масло для жарки оливковое', 14),
#  ('масло сливочное чабан', 14),
#  ('масло сливочнон', 14),
#  ('масло сливояное', 14),
#  ('масло подсолнечное рафинированное слобода', 14),
#  ('масло оливковое для жарки 1л', 14),
#  ('молоко шоколадное чудо', 14),
#  ('молоко 3,2%', 14),
#  ('молоко 1,5 л', 14),
#  ('молоко parmalat 0,5', 14),
#  ('молоко топленое простоквашино', 14),
#  ('молоко 2,5 простоквашино', 14),
#  ('молоко 2,5 домик в деревне', 14),
#  ('молоко aroy-d кокосовое', 14),
#  ('молотый перец', 14),
#  ('молочные', 14),
#  ('молочные продукты питания', 14),
#  ('молооко', 14),
#  ('мыло твердое хозяйственное', 14),
#  ('калория', 14),
#  ('малоежка детское питание педиашур', 13),
#  ('малин', 13),
#  ('малиновый', 13),
#  ('малина сублимированная', 13),
#  ('малютка 4 1200гр', 13),
#  ('майонез московский', 13),
#  ('майонез 800 мл', 13),
#  ('масло рыжиковое', 13),
#  ('масло сливочно', 13),
#  ('масло сливочное правильное', 13),
#  ('масло сливочноп', 13),
#  ('масло сливочнле', 13),
#  ('масло монини оливковое', 13),
#  ('масло правильное', 13),
#  ('масло виноградное', 13),
#  ('масло без запаха подсолнечное', 13),
#  ('молоко пармелат', 13),
#  ('молоко не молоко', 13),
#  ('молоко вологодское ультрапастеризованное', 13),
#  ('молоко озон фреш', 13),
#  ('молоко эконива professional', 13),
#  ('молоко 1,5 %', 13),
#  ('молочный шоколад милка', 13),
#  ('молочный коктейль чудо', 13),
#  ('молочные продукты творог', 13),
#  ('молочная каша агуша', 13),
#  ('молочная каша фрутоняня', 13),
#  ('моложеное', 13),
#  ('мыло пенка', 13),
#  ('мыло 5л', 13),
#  ('мыло synergetic 5л', 13),
#  ('мыло synergetic для рук', 13),
#  ('палочки кузя', 13),
#  ('палочки для ушей детские с ограничителем', 13),
#  ('палочки ушные с ограничителем', 13),
#  ('малышам сок', 12),
#  ('майонез 700 мл', 12),
#  ('майонез зеро', 12),
#  ('масло растительное altero', 12),
#  ('масло сливочное 200гр', 12),
#  ('масло сливочное82.5 белорусское', 12),
#  ('масло сливлчное', 12),
#  ('масло сладко сливочное', 12),
#  ('масло горчичное', 12),
#  ('масло пармалат', 12),
#  ('масло олейна подсолнечное', 12),
#  ('молоко бариста кокосовое', 12),
#  ('молоко сгущённое', 12),
#  ('молоко вологжанка', 12),
#  ('молоко топленое ультрапастеризованное', 12),
#  ('молоко тёма', 12),
#  ('молоко 2 литра правильное', 12),
#  ('молоко ультрапастеризованное 3.2 село зеленое', 12),
#  ('молочные кашки', 12),
#  ('мыло жидкое 5 литров', 12),
#  ('мыло хозяйственное твердое', 12),
#  ('мыло интимной гигиены', 12),
#  ('мыло отбеливающее', 12),
#  ('калоген', 12),
#  ('мальтизерс конфеты', 11),
#  ('маковая булочка', 11),
#  ('майоеез', 11),
#  ('майонез слобода провансаль', 11),
#  ('майонез веганский', 11),
#  ('майонез ряба провансаль', 11),
#  ('майонез 0', 11),
#  ('майонезный соус', 11),
#  ('масло растительное нерафинированное подсолнечное', 11),
#  ('масло для фритюра', 11),
#  ('масло сливочное82.5 экомилк', 11),
#  ('масло сливочнре', 11),
#  ('масло соленое', 11),
#  ('масло олив', 11),
#  ('масло волгодонское', 11),
#  ('масло кокосовое для еды', 11),
#  ('масло parmalat', 11),
#  ('масло monini', 11),
#  ('маомелад', 11),
#  ('молоко пармалат 3,5% 1 л', 11),
#  ('молоко безлактозный', 11),
#  ('молоко растительное овсяное', 11),
#  ('молоко сгущенное алексеевское', 11),
#  ('молоко долгоиграющий', 11),
#  ('молоко концентрированное', 11),
#  ('молоко 0,5 процента', 11),
#  ('молоко 3,6', 11),
#  ('молоко ореховое без сахара', 11),
#  ('молоко эконива 3.2', 11),
#  ('молоко гармония', 11),
#  ('молоко ультрапастеризованное 3.2 1 литр', 11),
#  ('молоко ультрапастеризованное 2,5 эконива', 11),
#  ('молоко цельное отборное', 11),
#  ('молоко.', 11),
#  ('мыло для душа', 11),
#  ('мыло для рук жидкое synergetic', 11),
#  ('мыло для мытья посуды', 11),
#  ('мыло дегтярное', 11),
#  ('мыло жидкое для рук 5л', 11),
#  ('мыло жидкое 5л', 11),
#  ('мыло пенка для рук', 11),
#  ('мыло пятновыводитель', 11),
#  ('мыло 5 л', 11),
#  ('сало соленое белорусское', 11),
#  ('малиновый сметанник', 10),
#  ('маленькое чудо', 10),
#  ('мароденое', 10),
#  ('маковый штрудель', 10),
#  ('майонез домашний', 10),
#  ('майонез рикко на перепелиных яйцах', 10),
#  ('майонез mr.ricco', 10),
#  ('майонец', 10),
#  ('майонех', 10),
#  ('масло растительное подсолнечное рафинированное 1 л', 10),
#  ('масло растительное 2л', 10),
#  ('масло для волос несмываемое', 10),
#  ('масло сливочное 72.5', 10),
#  ('масло сливочное 380 г', 10),
#  ('масло сливочное82.5 вологодское', 10),
#  ('масло сливочгое', 10),
#  ('масло село зеленое', 10),
#  ('масло массажное для тела', 10),
#  ('масло подсолнечное 0,5', 10),
#  ('масло оливковое filippo berio', 10),
#  ('масло озон', 10),
#  ('масло тыквенное холодного отжима', 10),
#  ('масло тысяча', 10),
#  ('масло топленое сливочное белорусское', 10),
#  ('масло арахисовое', 10),
#  ('масло 82.5', 10),
#  ('молоко простоквашино отборное', 10),
#  ('молоко безлак', 10),
#  ('молоко безлактоз', 10),
#  ('молоко безлактозная', 10),
#  ('молоко без лактозное', 10),
#  ('молоко банановое planto', 10),
#  ('молоко снежок', 10),
#  ('молоко кокосовое aroy', 10),
#  ('молоко клевер', 10),
#  ('молоко 3,2 12шт', 10),
#  ('молоко 3,2 1 л', 10),
#  ('молоко 3.2 эконива', 10),
#  ('молоко молоко', 10),
#  ('молоко агуша 925', 10),
#  ('молоко асеньевская', 10),
#  ('молоко planto без сахара', 10),
#  ('молоко топленое эконива', 10),
#  ('молоко тема 0,5', 10),
#  ('молоко ультропастирезованное', 10),
#  ('молоко 6', 10),
#  ('молокоо', 10),
#  ('молоко3.2', 10),
#  ('молочная детская каша', 10),
#  ('молочко', 10),
#  ('мыло дуру твердое', 10),
#  ('мыло жидкое для кухни', 10),
#  ('мыло safeguard', 10),
#  ('балон для освежителя воздуха', 10),
#  ('маленькие пельмени', 9),
#  ('маленький сок', 9),
#  ('маленькое чудо конфеты', 9),
#  ('малако', 9),
#  ('майонез с лимонным соком', 9),
#  ('майони', 9),
#  ('масло расти', 9),
#  ('масло для салата оливковое', 9),
#  ('масло для массажа лица', 9),
#  ('масло сливочное порционное', 9),
#  ('масло сливочное коровка из кореновки', 9),
#  ('масло сливочное president', 9),
#  ('масло сливочное 400', 9),
#  ('масло сливочное экомилк 450гр', 9),
#  ('масло слив сливочное', 9),
#  ('масло слиаочное', 9),
#  ('масло с базиликом', 9),
#  ('масло спрей для жарки', 9),
#  ('масло гзи', 9),
#  ('масло подсолнечное рафинированное дезодорированное', 9),
#  ('масло оливковое с трюфелем', 9),
#  ('масло оливковое extra', 9),
#  ('масло оливковое 500мл', 9),
#  ('масло оливкое', 9),
#  ('масло виноградных косточек', 9),
#  ('масло алтеро', 9),
#  ('масло белорусское сливочное', 9),
#  ('масло 1000 озер сливочное', 9),
#  ('масло из вологды', 9),
#  ('маалокс таблетки', 9),
#  ('мамло подсолнечное', 9),
#  ('маойнез', 9),
#  ('молоко безлакт', 9),
#  ('молоко безлактозное 1 л беларуссия', 9),
#  ('молоко безлактозное пармалат 1,8', 9),
#  ('молоко безлактозное село зеленое', 9),
#  ('молоко безлактозное детское', 9),
#  ('молоко безлактозное агрокомплекс', 9),
#  ('молоко бабулины продукты', 9),
#  ('молоко низколактозное', 9),
#  ('молоко русское', 9),
#  ('молоко стерилизованное 3,2', 9),
#  ('молоко сгущенка', 9),
#  ('молоко сухое', 9),
#  ('молоко 4', 9),
#  ('молоко 0,2 л', 9),
#  ('молоко 3,2 parmalat', 9),
#  ('молоко 3,2 безлактозное', 9),
#  ('молоко обезжиренное parmalat', 9),
#  ('молоко маруся', 9),
#  ('молоко эко', 9),
#  ('молоко ультрапастеризованное эконива', 9),
#  ('молоко упаковка', 9),
#  ('молоко ozon fresh', 9),
#  ('молоком', 9),
#  ('молокуша вязанка', 9),
#  ('молока безлактозное', 9),
#  ('молотый перец черный', 9),
#  ('молочные привидения', 9),
#  ('молочная смесь 2', 9),
#  ('молочная кашка', 9),
#  ('мыло дав жидкое', 9),
#  ('мыло жидкое для рук детское', 9),
#  ('мыло dove жидкое', 9),
#  ('мыло dove твердое', 9),
#  ('мыло хозяйственное 72% натуральное', 9),
#  ('мыло xiaomi сменный блок', 9),
#  ('палочки для суши', 9),
#  ('палочки сырные', 9),
#  ('балон с сжатым воздухом для пк', 9),
#  ('алое вера гель', 9),
#  ('малое', 8),
#  ('малоежка 850', 8),
#  ('малосоленая рыба', 8),
#  ('малиновая тарталетка', 8),
#  ('малютка 3 1200гр', 8),
#  ('майонез безлактозный', 8),
#  ('майонез слобода 800 мл', 8),
#  ('майонез сметанковый', 8),
#  ('майонез 400', 8),
#  ('майонез обезжиренный', 8),
#  ('майонез 200', 8),
#  ('масоины', 8),
#  ('мацони агрокомплекс', 8),
#  ('масло растительное слобода', 8),
#  ('масло для ногтей', 8),
#  ('масло для массажа тела', 8),
#  ('масло сливочное белорусское', 8),
#  ('масло сливосное', 8),
#  ('масло гх', 8),
#  ('масло подсолнечное с добавлением оливкового', 8),
#  ('масло подсолнечное 0,5 л', 8),
#  ('масло оливковое с подсолнечным', 8),
#  ('масло оливковое extra virgin 1л', 8),
#  ('масло облепиховое', 8),
#  ('масло одивковое', 8),
#  ('масло холодного отжима', 8),
#  ('масло кунжутное для еды', 8),
#  ('масло топленое белорусское', 8),
#  ('масло авакадо', 8),
#  ('масло безлактозный', 8),
#  ('мачло сливочное', 8),
#  ('молоко без лактозы простоквашино', 8),
#  ('молоко без сахара растительное', 8),
#  ('молоко блок', 8),
#  ('молоко рисовое', 8),
#  ('молоко сгущеное алексеевское', 8),
#  ('молоко дороганов', 8),
#  ('молоко 0.5% процентов', 8),
#  ('молоко в тетрапаке', 8),
#  ('молоко вологодское', 8),
#  ('молоко виола 1,5', 8),
#  ('молоко 3,2 упаковка', 8),
#  ('молоко 3,2 вкуснотеево', 8),
#  ('молоко 3.2 село зелёное', 8),
#  ('молоко отборное простоквашино', 8),
#  ('молоко агрокомплекс 2,5', 8),
#  ('молоко асеньевское', 8),
#  ('молоко 1,8 процента', 8),
#  ('молоко 1.5 л', 8),
#  ('молоко planto barista', 8),
#  ('молоко ультрапастеризованное 1 л', 8),
#  ('молокь', 8),
#  ('молочный улун чай в пакетиках', 8),
#  ('молочные приведения мармелад', 8),
#  ('молочная каша нестле', 8),
#  ('мелотонин', 8),
#  ('мыло детское твердое', 8),
#  ('мыло детское кусковое', 8),
#  ('мыло ушастый нянь от пятен', 8),
#  ('мыло kix', 8),
#  ('мтлоко', 8),
#  ('сало с чесноком', 8),
#  ('малиновый йогурт', 7),
#  ('маленькая кукуруза', 7),
#  ('малютка 0 смесь', 7),
#  ('маковый рулет с изюмом', 7),
#  ('майонез скит провансаль', 7),
#  ('майонез сметанный слобода', 7),
#  ('майонез в ведре', 7),
#  ('майонез оливковый слобода', 7),
#  ('майонез 30', 7),
#  ('майонеж', 7),
#  ('масоо', 7),
#  ('мауони', 7),
#  ('масло рас', 7),
#  ('масло рисовое monini', 7),
#  ('масло для душа la roche posay', 7),
#  ('масло для новорожденных', 7),
#  ('масло сливочное вологодское из вологды', 7),
#  ('масло сливочное маленькое', 7),
#  ('масло сыродавленное', 7),
#  ('масло гхи топленое белорусское', 7),
#  ('масло массажное детское', 7),
#  ('масло лососевое', 7),
#  ('масло подсолн', 7),
#  ('масло подсолнечное растительное', 7),
#  ('масло подсолнечное 5 литров', 7),
#  ('масло подсолнечное altero', 7),
#  ...]

# %% [markdown]
# # Генеративные подсказки

# %%
user_sequences = (
    search_events.group_by("user_id", maintain_order=True)
    .agg(
        pl.struct(pl.col("timestamp"), pl.col("search_query")).alias("user_actions")
    )
)

# %%
user_sequences.head()
# Out:
# shape: (5, 2)
# ┌──────────┬─────────────────────────────────┐
# │ user_id  ┆ user_actions                    │
# │ ---      ┆ ---                             │
# │ i32      ┆ list[struct[2]]                 │
# ╞══════════╪═════════════════════════════════╡
# │ 10904261 ┆ [{2024-05-15 15:42:19,"ламбер … │
# │ 2799838  ┆ [{2024-05-09 19:12:06,"кетчуп"… │
# │ 1156024  ┆ [{2024-05-19 21:19:14,"турецки… │
# │ 1969650  ┆ [{2024-05-30 08:42:05,"набор д… │
# │ 5184152  ┆ [{2024-05-13 15:37:06,"чеснок … │
# └──────────┴─────────────────────────────────┘

# %%
user_sequences_list = user_sequences[["user_actions"]].rows()

# %%
user_sequences_list_sorted = [sorted(x[0], key=lambda x: x["timestamp"]) for x in user_sequences_list]

# %%
user_sequences_list_sorted[0]
# Out:
# [{'timestamp': datetime.datetime(2024, 5, 15, 15, 40, 1),
#   'search_query': 'шницель куриный'},
#  {'timestamp': datetime.datetime(2024, 5, 15, 15, 40, 35),
#   'search_query': 'експонента exponenta напиток'},
#  {'timestamp': datetime.datetime(2024, 5, 15, 15, 41, 5),
#   'search_query': 'кофе в капсулах'},
#  {'timestamp': datetime.datetime(2024, 5, 15, 15, 42, 19),
#   'search_query': 'ламбер сыр'},
#  {'timestamp': datetime.datetime(2024, 5, 17, 14, 8, 43),
#   'search_query': 'шницель куриный'},
#  {'timestamp': datetime.datetime(2024, 5, 17, 14, 9, 9),
#   'search_query': 'експонента exponenta напиток'},
#  {'timestamp': datetime.datetime(2024, 5, 17, 14, 10, 38),
#   'search_query': 'лечо'},
#  {'timestamp': datetime.datetime(2024, 5, 27, 13, 18, 4),
#   'search_query': 'гранола настин сластин'},
#  {'timestamp': datetime.datetime(2024, 5, 27, 13, 18, 13),
#   'search_query': 'гранола'},
#  {'timestamp': datetime.datetime(2024, 5, 27, 13, 20, 15),
#   'search_query': 'гранола настин сластин'}]

# %%
user_texts = [[y["search_query"] for y in x] for x in user_sequences_list_sorted]

# %% [markdown]
# ## Train tokenizer

# %%
user_texts_joined = [" ".join(x) for x in user_texts]

with open("tokenizer_train_data.txt", "w") as file:
    file.write("\n".join(user_texts_joined) + "\n")

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece
from tokenizers.trainers import WordPieceTrainer
from tokenizers.pre_tokenizers import Whitespace


tokenizer = Tokenizer(WordPiece())

trainer = WordPieceTrainer(
    vocab_size=8_192,
    special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]", "[SEARCH]", "[PREFIX]", "[EOQ]"]
)

tokenizer.pre_tokenizer = Whitespace()

tokenizer.train(files=["tokenizer_train_data.txt"], trainer=trainer)

# %%
tokenizer.save("WPC_tokenizer.json")

# %%
from tokenizers import Tokenizer

tokenizer = Tokenizer.from_file("WPC_tokenizer.json")

encoded = tokenizer.encode(
    "машина на пульте управления"
)
encoded.tokens
# Out:
# ['машина', 'на', 'пульт', '##е', 'уп', '##ра', '##в', '##ления']

# %%
tokenizer.encode("[SEARCH]").ids
# Out:
# [5]

# %% [markdown]
# ## Построим обучающую выборку для языковой модели

# %%
MAX_LM_LENGTH = 256

# %%
[PREFIX] мол [SEARCH] молоко [EOQ] [PREFIX] с [SEARCH] сыр плавленный [EOQ]

# %%
def select_random_prefix(text: str) -> str:
    rnd = random.randint(1, len(text))
    return text[:rnd]


def make_training_example(search_queries: list[str]) -> tuple[list[int], list[str], list[bool]]:
    prompt_token_ids = []
    label_masks = []

    for q in search_queries:

        prefix = select_random_prefix(q)
        tokenized_prefix = tokenizer.encode(prefix)
        tokenized_query = tokenizer.encode(q)
        if len(prompt_token_ids) + len(tokenized_prefix.ids) + len(tokenized_query.ids) + 3 > MAX_LM_LENGTH:
            break

        prompt_token_ids.extend(tokenizer.encode("[PREFIX]").ids)
        label_masks.append(False)

        prompt_token_ids.extend(tokenized_prefix.ids)
        label_masks.extend([False for _ in tokenized_prefix.ids])
        
        prompt_token_ids.extend(tokenizer.encode("[SEARCH]").ids)
        label_masks.append(False)

        prompt_token_ids.extend(tokenized_query.ids)
        label_masks.extend([True for _ in tokenized_query.ids])

        prompt_token_ids.extend(tokenizer.encode("[EOQ]").ids)
        label_masks.append(True)

    prompt_token_ids = [tokenizer.encode("[PAD]").ids[0] for _ in range(MAX_LM_LENGTH - len(prompt_token_ids))] + prompt_token_ids
    label_masks = [False for _ in range(MAX_LM_LENGTH - len(label_masks))] + label_masks

    return prompt_token_ids, label_masks

# %%
training_example = make_training_example(user_texts[0])

# %%
training_example[1]
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
len(training_example[0])
# Out:
# 256

# %%
lm_training_data = []
for user_chain in tqdm(user_texts):
    training_sample = make_training_example(user_chain)
    lm_training_data.append((training_sample[0], training_sample[2]))

# %%
import pickle

with open("lm_training_data.pickle", "rb") as f:
    lm_training_data = pickle.load(f)

# %%
lm_training_data[0]
# Out:
# ([3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   6,
#   6756,
#   4391,
#   5,
#   6756,
#   4391,
#   7,
#   6,
#   173,
#   3408,
#   4691,
#   5,
#   173,
#   3408,
#   4691,
#   3827,
#   3812,
#   7,
#   6,
#   3039,
#   5,
#   3039,
#   170,
#   4807,
#   7,
#   6,
#   7821,
#   1707,
#   1659,
#   5,
#   5315,
#   2942,
#   7,
#   6,
#   6756,
#   2990,
#   5,
#   6756,
#   4391,
#   7,
#   6,
#   173,
#   3408,
#   5361,
#   5,
#   173,
#   3408,
#   4691,
#   3827,
#   3812,
#   7,
#   6,
#   7847,
#   5,
#   7847,
#   7,
#   6,
#   4552,
#   5,
#   5403,
#   4119,
#   2913,
#   3897,
#   7473,
#   1665,
#   7,
#   6,
#   4552,
#   1661,
#   5,
#   5403,
#   7,
#   6,
#   4552,
#   5,
#   5403,
#   4119,
#   2913,
#   3897,
#   7473,
#   1665,
#   7],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True])

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from transformers import LlamaForCausalLM, LlamaConfig, AdamW

# %%
class CustomDataset(Dataset):
    def __init__(self, data: tuple[list[int], list[bool]]):
        self.data = data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx: int) -> tuple[torch.LongTensor, torch.BoolTensor]:
        token_ids, label_masks = self.data[idx]
        return (
            torch.LongTensor(token_ids).unsqueeze(0),
            torch.BoolTensor(label_masks).unsqueeze(0),
        )


def collate_fn(data):
    token_ids, label_masks = zip(*data)
    return (
        torch.concat(token_ids, dim=0),
        torch.concat(label_masks, dim=0),
    )

# %%
dataset = CustomDataset(lm_training_data)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# %%
model = LlamaForCausalLM(
    config=LlamaConfig(
        vocab_size=8192,
        hidden_size=256,
        intermediate_size=768,
        num_hidden_layers=4,
        num_attention_heads=4,
        num_key_value_heads=2,
        hidden_act="silu",
        max_position_embeddings=512,
        pad_token_id=3,
        initializer_range=0.02,
        rope_theta=1000.,
    )
)

# %%
loss_fct = nn.CrossEntropyLoss(ignore_index=-100)
optimizer = AdamW(model.parameters(), lr=1e-4)

model.train()
# Out:
# /Users/dandrosov/Desktop/recsys_ir_course/venvs/3_10/lib/python3.12/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(8192, 256, padding_idx=3)
#     (layers): ModuleList(
#       (0-3): 4 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=256, out_features=256, bias=False)
#           (k_proj): Linear(in_features=256, out_features=128, bias=False)
#           (v_proj): Linear(in_features=256, out_features=128, bias=False)
#           (o_proj): Linear(in_features=256, out_features=256, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=256, out_features=768, bias=False)
#           (up_proj): Linear(in_features=256, out_features=768, bias=False)
#           (down_proj): Linear(in_features=768, out_features=256, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((256,), eps=1e-06)
#         (post_attention_layernorm): LlamaRMSNorm((256,), eps=1e-06)
#       )
#     )
#     (norm): LlamaRMSNorm((256,), eps=1e-06)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=256, out_features=8192, bias=False)
# )

# %%
start_time = time.time()
losses = []


for i, batch in enumerate(dataloader, 1):
    input_ids, label_masks = batch
    labels = input_ids.clone()

    outputs = model(input_ids=input_ids, labels=labels)

    logits = outputs.logits
    shift_logits = logits[:, :-1, :]
    shift_labels = labels[:, 1:]
    shift_label_masks = label_masks[:, 1:]

    active_loss = shift_label_masks.reshape(-1)
    active_logits = shift_logits.reshape(-1, shift_logits.size(-1))[active_loss]
    active_labels = shift_labels.reshape(-1)[active_loss]
    
    loss = loss_fct(active_logits, active_labels)
    losses.append(loss.item())

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    if i % 100 == 0:
        print(f"Iteration {i}, time taken = {time.time() - start_time}: loss={sum(losses) / len(losses)}")
        start_time = time.time()
        losses = []
# Out:
# Iteration 100, time taken = 8.334563970565796: loss=7.4609723567962645
# Iteration 200, time taken = 8.098393201828003: loss=6.544859580993652
# Iteration 300, time taken = 8.050681829452515: loss=6.211402144432068
# Iteration 400, time taken = 8.130712032318115: loss=6.052275166511536
# Iteration 500, time taken = 8.404176235198975: loss=6.075403165817261
# Iteration 600, time taken = 8.28242301940918: loss=5.804515557289124
# Iteration 700, time taken = 8.225300073623657: loss=5.781954045295715
# Iteration 800, time taken = 8.615727186203003: loss=5.748478360176087
# Iteration 900, time taken = 8.221994161605835: loss=5.484619045257569
# Iteration 1000, time taken = 8.181087970733643: loss=5.54943244934082
# Iteration 1100, time taken = 8.307843208312988: loss=5.46842031955719
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 23
#      20 loss = loss_fct(active_logits, active_labels)
#      21 losses.append(loss.item())
# ---> 23 loss.backward()
#      24 optimizer.step()
#      25 optimizer.zero_grad()
#
# File ~/Desktop/recsys_ir_course/venvs/3_10/lib/python3.12/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/Desktop/recsys_ir_course/venvs/3_10/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/Desktop/recsys_ir_course/venvs/3_10/lib/python3.12/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
model.eval()

# %%
model_loaded = LlamaForCausalLM.from_pretrained("small_suggest_lm")
model_loaded.eval()
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(8192, 256, padding_idx=3)
#     (layers): ModuleList(
#       (0-3): 4 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=256, out_features=256, bias=False)
#           (k_proj): Linear(in_features=256, out_features=128, bias=False)
#           (v_proj): Linear(in_features=256, out_features=128, bias=False)
#           (o_proj): Linear(in_features=256, out_features=256, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=256, out_features=768, bias=False)
#           (up_proj): Linear(in_features=256, out_features=768, bias=False)
#           (down_proj): Linear(in_features=768, out_features=256, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((256,), eps=1e-06)
#         (post_attention_layernorm): LlamaRMSNorm((256,), eps=1e-06)
#       )
#     )
#     (norm): LlamaRMSNorm((256,), eps=1e-06)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=256, out_features=8192, bias=False)
# )

# %%
prompt = "[PREFIX] мо [SEARCH] молоко [PREFIX] вод [SEARCH] вода 5л [PREFIX] сыр плав [SEARCH] сыр плавленный [PREFIX] бр [SEARCH]"

prompt_token_ids = tokenizer.encode(prompt).ids
input_ids = torch.LongTensor(prompt_token_ids).unsqueeze(0)

# %%
num_beams = 5
max_length = 5

# %%
with torch.no_grad():
    output_ids = model_loaded.generate(
        input_ids,
        max_length=len(prompt_token_ids) + max_length,
        num_beams=num_beams,
        early_stopping=True,
        pad_token_id=3,
        eos_token_id=7,
        return_dict_in_generate=True,
        output_scores=True,
        num_return_sequences=5,
    ).sequences

# %%
for i, generated_ids in enumerate(output_ids.tolist()):
    text = tokenizer.decode(generated_ids[-max_length:], skip_special_tokens=False)
    print(f"{text}")
# Out:
# бр [SEARCH] брокколи [EOQ] [PAD]
# бр [SEARCH] брынза [EOQ] [PAD]
# бр [SEARCH] брокколи замороженные [EOQ]
# бр [SEARCH] брокколи свежая [EOQ]
# бр [SEARCH] брокколи пюре [EOQ]
